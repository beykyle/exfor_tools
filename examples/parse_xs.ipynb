# %%
import exfor_tools
# Out:
# Using database version X4-2024-12-31 located in: /mnt/home/beyerkyl/x4db/unpack_exfor-2024/X4-2024-12-31

# %%
import jitr

# %%
entry = exfor_tools.ExforEntry(
    entry="10817",
    reaction=jitr.reactions.reaction.TotalReaction(
        target=(120,50),
        projectile=(1,0),
    ),
    quantity="XS",
    vocal=True,
)

# %%
entry.measurements
# Out:
# []

# %%
entry = exfor_tools.ExforEntry(
    entry="12785",
    reaction=jitr.reactions.reaction.ElasticReaction(
        target=(40,20),
        projectile=(1,0),
    ),
    quantity="dXS/dA",
    vocal=True,
   # filter_kwargs={"allow_cos" : True}
)
entry.measurements
# Out:
# Found subentry 12785002 with the following columns:
# ['EN', 'EN-RSL', 'ANG-CM', 'DATA-CM', 'DATA-ERR']
# ...

# %%
exfor_tools.__version__
# Out:
# '0.5.dev17+ga3f176d6e'
